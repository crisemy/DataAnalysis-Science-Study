# %%
# More examples are here https://seaborn.pydata.org/examples/index.html
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="dark")

# Simulate data from a bivariate Gaussian
n = 10000
mean = [0, 0]
cov = [(2, .4), (.4, .2)]
rng = np.random.RandomState(0)
x, y = rng.multivariate_normal(mean, cov, n).T

# Draw a combo histogram and scatterplot with density contours
f, ax = plt.subplots(figsize=(6, 6))
sns.scatterplot(x=x, y=y, s=5, color=".15")
sns.histplot(x=x, y=y, bins=50, pthresh=.1, cmap="mako")
sns.kdeplot(x=x, y=y, levels=5, color="w", linewidths=1)
# Out:
# <Axes: >

# %%
import pandas as pd
stats = pd.read_csv('Demographic-Data.csv')
stats
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
### Introduction to SEABORN. A visualization graph. Go to https://seaborn.pydata.org/examples/index.html to get more Graph examples
import matplotlib.pyplot as plt
import seaborn as sns


stats.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
# Distribution:
vis1 = sns.displot(stats["Internet users"]) # It shows up a count of Internet Users

# %%
# Distribution: Changing the quantity of bins
vis1 = sns.displot(stats["Internet users"], bins=30)

# %%
# Boxplots:
vis2 = sns.boxplot(data=stats, x="Income Group", y="Birth rate")

# %%
vis3 = sns.lmplot(data=stats, x='Internet users', y='Birth rate', \
                  fit_reg=False, hue='Income Group', \
                   scatter_kws={"s":80} )   
# LM stands for Lineal Model. 
# fit_reg is for not seeing a specific line, hue is for colors, scatter is for sizing. It passes a python dictionary. 
# Scatter increases the size of the bullet points
# It can be specified as: sns.lmplot( x='Internet users', y='Birth rate, data=stats). I mean, the order changes...
